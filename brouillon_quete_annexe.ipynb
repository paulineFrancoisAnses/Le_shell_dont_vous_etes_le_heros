# %% [markdown]
# # TEST DE A VOUS DE JOUER

# %% [markdown]
# Fatigué de ce bordel, vous déménagez à futurland. Avantage = les gens d'ici ne connaissent pas ce pays car caché dans cet univers
#
# Vous faites le choix de déplacer toute votre cabane et tous les bien qu'elle contient.
#
# A futurland, vous l'installez entre magasin_d_automates et musee_des_machines_a_vapeur, sous le nom de maison_d_hermite. Vous espérez qu'avec ce nom, on vous laissera en paix.

# %%
cp -r ../foret_enchantee/lisiere_foret/ma_jolie_cabane/ ville/maison_d_hermite

# %% [markdown]
# Veut se rendre à la fête forraine via la gare multirails

# %% [markdown]
# Liste de personnes dans un fichier par lieu dans la ville. Il faut en chercher un précis (boucle for, if grep ok)

# %% [markdown]
# # Autre quete annexe
#
# Faire déménager les elfes de la foret à la ville de reveland en les décachant.
#
# Ils tombent malades
#
# Construire l'hopital et accueillir (créer fichier en boucle for) 50 malades.
#
# Aller chez les ogres. Envahi par les nains de jardin, vous devez aller les éliminer d'abord (rm)
#
# Puis chez les ogres, allez chercher le fruit. Le ramener dans le village des elfes de reveland.
#
# Pour qu'il agisse, il faut le compresser (zip)

# %% [markdown]
# # Quete en awk
#
# Sur des étagères (un dossier par étagères), on a des potions (fichier texte), avec les initiales des produits qui les composent. (exemple : sel, poivre, riz = spr)
#
# Pour trouver la bonne fiole, on a un fichier :
# fichier de maladie :
#
# | maladie | colonnes | ingredient 1 | ingredient 2 | ingrédient 3 |
# | --- | --- | --- | --- | --- |
# | rhume | 3, 6, 8 | chou | sel | riz |
# | gangrene | 1,5,7 | sel | poivre | poux (?) |

# %% [markdown]
# Pour avoir la bonne fiole, il faut awk $1 == la maladie qu'on souhaite traiter
# Print la colonne $2
# Pour pouvoir print les colonnes indiquées.

# %% [markdown]
# # Mini quête annexe
#
# Créé un fichier nommé "mini_quete" dans le dossier cinema qui dit "Allez parler au gérant du cinéme"
# Dans le fichier "gerant_du_cinema.txt", dire qu'il souhaite à partir du dossier "film à l'affiche" connaitre :
#
# Fichiers (un par film) :
# colonne 1 (catégorie) - Colonne 2 (age)
# Enfant - 4
# adulte - 30
# personne agées - 69
# ado - 15
# X fois - X ages différents
#
# Question 1 : connaitre le film à l'affiche qui attire le plus les personnes agées (cut -f1 | sort | uniq -c)
#
# Question 2 : Pour le film Bidule, combien de personne ont strictement moins de 30 ans. awk 'BEGIN{nb=0}{if($2 < 30){nb=nb+1}}END{print nb}'
#
# Question 3 : Quelle est la moyenne d'âge du film tartampion ? awk 'BEGIN{age=0}{age=age+$2}END{print age/NR}'

# %% [markdown]
# # Mini quête annexe
#
# Bijouterie :
# dossier "vitrine1 et vitrine2", fichiers bague_XXX, collier_XXX, bracelet_XXX, boucle_oreille_XXX
#
# Question 1 : Vendez-vous des bagues ?
# commande : if [ -n "$(ls vitrine1/* | grep bague)" ]; then echo "bien sur que je vends des bagues"; else "Désolé, je n'en ai plus ici"; fi
# if [ -n "$(ls vitrine2/* | grep bague)" ]; then echo "bien sur que je vends des bagues"; else "Désolé, je n'en ai plus ici"; fi
#
# Question 2 : Ma compagne souhaite une bague en or entre 24 et 34 carats ou avec diamants bleus et au moins 800€
# (le nom des fichiers sera : bague_or_26_diamant_bleu_950.txt afin de faire un sed de .txt, puis de voir que ces noms sont juste un tableau à passer dans awk : awk 'BEGIN{FS="_"}{if($2=="or" && (($3 >= 24 && $3 <= 34) || ($4 == "diamant" && $5 == "bleu")) && $6 > 800}'

# %% [markdown]
#
# ## A vous de jouer... <img align="center"  src="data:image/png;base64,..." alt="Drawing" style="width :100px;"/>

# %% [markdown]
# Notion manquante : Créer un lien symbolique entre futurland et reveland
